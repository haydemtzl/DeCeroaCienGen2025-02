# %%
# Importar pandas
import pandas as pd

# %%
# Cargar mis datos como dataframe
data = pd.read_csv("notes.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#       Nombre  nota
# 0    Araceli     9
# 1     Manuel     5
# 2      Pablo     7
# 3      Iñigo     4
# 4      Mario     3
# 5       Raul     4
# 6   Verónica     6
# 7      Dario    10
# 8      Laura     4
# 9     Silvia     6
# 10   Eduardo     2
# 11    Susana     8
# 12     María     5

# %%
# Visualizar los primeros 5 renglones de mi dataset
data.head()
# Out:
#     Nombre  nota
# 0  Araceli     9
# 1   Manuel     5
# 2    Pablo     7
# 3    Iñigo     4
# 4    Mario     3

# %%
# Utilizar head con más renglones
data.head(7)
# Out:
#      Nombre  nota
# 0   Araceli     9
# 1    Manuel     5
# 2     Pablo     7
# 3     Iñigo     4
# 4     Mario     3
# 5      Raul     4
# 6  Verónica     6

# %%
# Función que me permite ver la estadistica descriptiva de las columnas numericas de mi dataset
data.describe()
# Out:
#             nota
# count  13.000000
# mean    5.615385
# std     2.364264
# min     2.000000
# 25%     4.000000
# 50%     5.000000
# 75%     7.000000
# max    10.000000

# %%
# USANDO PANDAS
# Calculo de la media
media = data["nota"].mean()
media
# Out:
# 5.615384615384615

# %%
# Calculo de la mediana
mediana = data["nota"].median()
mediana
# Out:
# 5.0

# %%
#Calculo de la moda
moda = data["nota"].mode()
moda
# Out:
# 0    4
# Name: nota, dtype: int64

# %%
#Calculo del rango
rango = data["nota"].max() - data["nota"].min()
rango
# Out:
# 8

# %%
#USANDO NUMPY
import numpy as np

# %%
np.mean(data["nota"])
# Out:
# 5.615384615384615

# %%
np.median(data["nota"])
# Out:
# 5.0

# %%
#Agregar varianza y desviación estandar
peyitos = [600,470,170,430,300]
np.mean(peyitos)
# Out:
# 394.0

# %%
np.median(peyitos)
# Out:
# 430.0

# %%
np.var(peyitos)
# Out:
# 21704.0

# %%
np.std(peyitos)
# Out:
# 147.32277488562318
